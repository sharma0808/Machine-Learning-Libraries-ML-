# %% [markdown]
# # Seaborn :
#                     For Data Visualization

# %%
##Univariate distribution

##sns.distplot(df['column_name'])
## kde=false

### when we are doing univariate distribution , only 1 column name(feature)
### is specified here

### we consider here only 1 feature that is 1 columns

# %%
## Bivariate distribution

### 2 features 
##sns.jointplot(df[column1], df[column2]); 

### this will work only when both are numerical 
## kind
### kind=hex ## hexbin plot
### kind=kde  ### kernel density estimation

# %%
### Plotting univariate distributions
### using seaborn library
## hsitogram only works for numerical data
## univariate distribution uses single variable, i.e single feature
## like age or like education

# %%
## distribution plot
### kde is bydefault true
### the curve we see is kde

sns.distplot(auto['Education'], color='green');

# %%
import numpy as np
import pandas as pd   # Reading and Writing CSV Files in Python with Pandas
import seaborn as sns   # Why sns?  It's a reference to The West Wing
import matplotlib.pyplot as plt  # seaborn is based on matplotlib
# %matplotlib inline 

sns.set(color_codes=True) # adds a nice background to the graphs
# tells python to actually display the graphs

# %%
data_set = pd.read_csv('https://raw.githubusercontent.com/Premalatha-success/Statistics/main/CardioGoodFitness-1.csv')

# %%
data_set.head()  # It will be displaying top 5 rows of dataset.
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
data_set.head(10) # It will be displaying top 10 rows of dataset
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47
# 5   TM195   20  Female         14     Partnered      3        3   32973     66
# 6   TM195   21  Female         14     Partnered      3        3   35247     75
# 7   TM195   21    Male         13        Single      3        3   32973     85
# 8   TM195   21    Male         15        Single      5        4   35247    141
# 9   TM195   21  Female         15     Partnered      2        3   37521     85

# %%
data_set.tail() # It will be displaying last 5 rows of dataset
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
data_set.tail(10) # It will be displaying last 10  rows of dataset
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 170    260
# 171    200
# 172    150
# 173    360
# 174    150
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
data_set.sample() # It will be randomly picking one rows of dataset
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 13   TM195   22  Female         14        Single      3        3   35247
#
#     Miles
# 13     75

# %%
data_set.sample()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 2   TM195   19  Female         14     Partnered      4        3   30699     66

# %%
data_set.sample(10) # It will be randomly picking 10 rows of dataset
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 50    TM195   29    Male         18     Partnered      3        3   68220
# 138   TM498   45    Male         16     Partnered      2        2   54576
# 43    TM195   27  Female         14     Partnered      2        3   45480
# 21    TM195   23    Male         16        Single      4        3   40932
# 159   TM798   27    Male         16     Partnered      4        5   83416
# 45    TM195   28  Female         16     Partnered      2        3   52302
# 130   TM498   35  Female         16        Single      3        2   50028
# 34    TM195   26  Female         14     Partnered      3        4   44343
# 170   TM798   31    Male         16     Partnered      6        5   89641
#
#      Miles
# 173    360
# 50      85
# 138     42
# 43      56
# 21      94
# 159    160
# 45      66
# 130     64
# 34     113
# 170    260

# %%
data_set.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 112   TM498   29  Female         14     Partnered      3        3   51165
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 162   TM798   28  Female         18     Partnered      6        5   92131
# 46    TM195   28    Male         14        Single      3        3   52302
# 98    TM498   25  Female         14        Single      3        4   43206
# 63    TM195   35    Male         16     Partnered      4        3   48891
# 7     TM195   21    Male         13        Single      3        3   32973
# 29    TM195   25  Female         14     Partnered      2        2   53439
# 136   TM498   40  Female         16        Single      3        3   57987
# 54    TM195   30    Male         14        Single      3        3   54576
#
#      Miles
# 112     95
# 174    150
# 162    180
# 46     103
# 98     127
# 63      85
# 7       85
# 29      47
# 136     85
# 54      85

# %%
data_set.shape # How many rows and How many columns
# Out:
# (180, 9)

# %%
data_set.dtypes  # It's dtypes not dtype
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
data_set.info() # if it is display <180 which mean that there are some missing values in that particular columns in dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# ## Plotting univariate distributions

# %% [markdown]
# The most convenient way to take a quick look at a univariate distribution in seaborn is the distplot() function. By default, this will draw a histogram and fit a kernel density estimate (KDE).

# %%
sns.distplot(data_set['Income']); # distplot mean distribution plot # It will work on numerical data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data_set['Income'], color="red"); ## Histogram work only for the numerical data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# we can turn the kde off and put a tic mark along the x-axis for every data point with rug
sns.distplot(data_set['Income'], kde = False);

# %% [markdown]
# ## Plotting bivariate distributions

# %% [markdown]
# It can also be useful to visualize a relationship between two variables. The easiest way to do this in seaborn is to use the jointplot() function, which creates a scatterplot of the two variables along with the histograms of each next to the appropriate axes.

# %%
sns.jointplot(data_set['Income'], data_set['Miles']) # both should be numerical data
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Hex Bin Plots
# We can make a hex bin plot that breaks the 2D area into hexagons and the number of points in each hexagon determines the color

# %%
sns.jointplot(data_set['Income'], data_set['Miles'], kind="hex")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data_set['Income'], data_set['Miles'], kind="hex", color="red")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data_set['Income'], data_set['Miles'], kind="hex", color="pink")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Kernel Density Estimation
# We can make a 2D estimation of the density also

# %%
sns.jointplot(data_set['Income'], data_set['Miles'], kind="kde")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Visualizing pairwise relationships in a dataset
# To plot multiple pairwise scatterplots in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame, it also draws the histogram of each variable on the diagonal Axes:
#
# Be careful about toggle scrolling in the cell menu!!!

# %%
sns.pairplot(data_set) ### all the numerical features are plotted against each other

# %% [markdown]
# ## Plotting with categorical data
# In a strip plot, the scatterplot points will usually overlap. This makes it difficult to see the full distribution of data. One easy solution is to adjust the positions (only along the categorical axis) using “jitter"

# %%
sns.stripplot(data_set['MaritalStatus'], data_set['Miles'], jitter=True); # one should be categorical other should be numerical
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.stripplot(data_set['MaritalStatus'], data_set['Miles']) # After removing jitter, scatter would be better
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Miles'>

# %% [markdown]
# A different approach would be to use the function swarmplot(), which positions each scatterplot point on the categorical axis and avoids overlapping points:

# %%
sns.swarmplot(data_set['MaritalStatus'], data_set['Miles']);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Boxplots
# Another common graph is a boxplot(). This kind of plot shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile, and then observations that fall outside this range are displayed independently.

# %%
sns.boxplot(data_set['MaritalStatus'], data_set['Miles'])  # one should be categorical other should be numerical
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Miles'>

# %%
sns.countplot(data_set['MaritalStatus'],hue=data_set['Miles'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
data_set.describe()  ## deals with only numerical data
                     ## count - Total number of rows
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
data_set.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# unique         NaN            NaN         NaN
# top            NaN            NaN         NaN
# freq           NaN            NaN         NaN
# mean      3.311111   53719.577778  103.194444
# std       0.958869   16506.684226   51.863605
# min       1.000000   29562.000000   21.000000
# 25%       3.000000   44058.750000   66.000000
# 50%       3.000000   50596.500000   94.000000
# 75%       4.000000   58668.000000  114.750000
# max       5.000000  104581.000000  360.000000
